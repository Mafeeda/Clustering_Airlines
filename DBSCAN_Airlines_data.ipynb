# %% [markdown]
# ## Importing necessary libraries

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import file

# %%
airline_data = pd.read_csv('EastWestAirlines.csv')
airline_data.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %% [markdown]
# ## Initial Investigation

# %%
airline_data.shape
# Out:
# (3999, 12)

# %%
airline_data.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airline_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airline_data = airline_data.rename(columns={'ID#':'ID', 'Award?':'Award'})
airline_data.head(5)
# Out:
#    ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0   1    28143           0          1          1          1          174
# 1   2    19244           0          1          1          1          215
# 2   3    41354           0          1          1          1         4123
# 3   4    14776           0          1          1          1          500
# 4   5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award
# 0            1                  0                0               7000      0
# 1            2                  0                0               6968      0
# 2            4                  0                0               7034      0
# 3            1                  0                0               6952      0
# 4           26               2077                4               6935      1

# %% [markdown]
# ## Normalizing the Data

# %%
scaled_airline_data = StandardScaler().fit_transform(airline_data.iloc[:,1:])
scaled_airline_data
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %% [markdown]
# ## DBSCAN Clustering

# %%
dbscan = DBSCAN(eps = 1,  min_samples = 4)
dbscan.fit(scaled_airline_data)
# Out:
# DBSCAN(eps=1, min_samples=4)

# %%
#Noisy samples are given the label -1.
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0])

# %%
# Adding clusters to dataset
airline_data['clusters']=dbscan.labels_
airline_data
# Out:
#         ID  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airline_data.groupby('clusters').agg(['mean']).reset_index()
# Out:
#   clusters           ID        Balance   Qual_miles cc1_miles cc2_miles  \
#                    mean           mean         mean      mean      mean
# 0       -1  1686.939509  184694.319471   977.113422  2.763705  1.058601
# 1        0  2181.546547   53978.079794     5.088374  1.658945  1.000000
# 2        1  1802.998179   62092.632969     9.785974  2.591985  1.000000
# 3        2  2557.230769   34806.538462     0.000000  1.000000  2.000000
# 4        3  1804.000000  202750.000000     0.000000  4.000000  1.000000
# 5        4  2534.142857   36413.428571     0.000000  1.000000  3.000000
# 6        5  1363.000000   60932.000000  1794.500000  3.750000  1.000000
# 7        6  1928.200000  164883.400000  1471.600000  1.000000  1.000000
# 8        7  3167.444444   27113.888889  2475.444444  1.000000  1.000000
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# ...

# %%
clusters = pd.DataFrame(dbscan.labels_,columns=['clusters'])
clusters.value_counts()


#-1 cluster represents outliers
# Out:
# clusters
#  0          2331
#  1          1098
# -1           529
#  2            13
#  7             9
#  4             7
#  6             5
#  5             4
#  3             3
# dtype: int64

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline_data['clusters'],airline_data['Balance'], c = dbscan.labels_)

# %%
# Plot Clusters
plt.figure(figsize=(10, 7))  
plt.scatter(airline_data['clusters'],airline_data['Bonus_miles'], c = dbscan.labels_)
